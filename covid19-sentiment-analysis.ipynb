txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_04.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_30.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_25.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_11.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_16.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_15.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_31.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_12.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_24.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_10.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_16.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_25.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_13.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_04.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_20.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_22.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_03.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_13.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_23.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_21.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_18.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_14.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_12.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_17.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_07.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_23.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_21.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_29.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_18.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_13.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_06.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_18.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_09.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_10.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_29.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_20.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_26.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_04.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_19.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_01.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_01.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_22.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_11.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_06.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_11.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_24.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_14.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_07.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_16.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_14.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_09.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_19.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_16.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_28.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_27.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_11.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_20.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_25.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_26.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_28.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_05.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_23.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_10.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_29.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_27.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_25.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_05.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_17.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_18.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_03.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_08.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_02.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_08.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_28.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_22.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_02.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_19.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_05.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_30.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_27.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_22.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_07.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_21.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_15.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_20.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_21.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_30.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_01.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_12.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_09.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_08.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_09.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_12.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_15.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_07.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_14.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_23.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_26.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_03.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_17.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_03_19.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_10.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_17.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_27.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_26.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_08.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_13.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_02.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_04_15.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_05_06.txt
# /kaggle/input/covid19-tweets-dataset/covid Tweets_ID/covid_2020_06_24.txt
# /kaggle/input/covid19-coronavirus/time_series_covid19_confirmed.xlsx
# /kaggle/input/covid19-coronavirus/time_series_covid19_recovered.xlsx
# /kaggle/input/covid19-coronavirus/2019_nCoV_data.csv
# /kaggle/input/covid19-coronavirus/time_series_covid19_deaths.xlsx
# /kaggle/input/covid19-in-india/IndividualDetails.csv
# /kaggle/input/covid19-in-india/ICMRTestingLabs.csv
# /kaggle/input/covid19-in-india/population_india_census2011.csv
# /kaggle/input/covid19-in-india/AgeGroupDetails.csv
# /kaggle/input/covid19-in-india/StatewiseTestingDetails.csv
# /kaggle/input/covid19-in-india/HospitalBedsIndia.csv
# /kaggle/input/covid19-in-india/covid_19_india.csv
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-26 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-27 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-30 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-23 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-18 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-20 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-25 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-17 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-22 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-28 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-29 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-21 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-16 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-19 Coronavirus Tweets.CSV
# /kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-24 Coronavirus Tweets.CSV
# /kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_recovered.csv
# /kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_deaths.csv
# /kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_confirmed.csv
# /kaggle/input/novel-corona-virus-2019-dataset/COVID19_open_line_list.csv
# /kaggle/input/novel-corona-virus-2019-dataset/COVID19_line_list_data.csv
# /kaggle/input/novel-corona-virus-2019-dataset/covid_19_data.csv
# /kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_deaths_US.csv
# /kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_confirmed_US.csv
# /kaggle/input/coronavirus-covid19-tweets/Countries.CSV

# %% [markdown]
# # Reading Data

# %%
# Reading data
df=pd.read_csv('/kaggle/input/coronavirus-covid19-tweets-late-april/2020-04-16 Coronavirus Tweets.CSV')
df.head()
# Out:
#              status_id              user_id            created_at  \
# 0  1250574628726214658   817072420947247104  2020-04-16T00:00:00Z
# 1  1250574627127975938             44728980  2020-04-16T00:00:00Z
# 2  1250574628671467521  1235017593649418241  2020-04-16T00:00:00Z
# 3  1250574628575010816             92174767  2020-04-16T00:00:00Z
# 4  1250574628201717760  1042498579909107712  2020-04-16T00:00:00Z
#
#        screen_name                                               text  \
# 0     Tu_IMSS_Coah  Para complementar la higiene de tus manos, el ...
# 1        ANCALERTS  PWDs from Tahanang Walang Hagdan get aid amid ...
# 2          julycio  #France ได้รับความทุกข์ทรมานจาก # ชุดการแยกตัว...
# 3    DZMMTeleRadyo  Target ng Department of Health na magkaroon ng...
# 4  ContraReplicaMX  La @SSalud_mx lanzó una nueva convocatoria esp...
#
#                     source  reply_to_status_id  reply_to_user_id  \
# 0                TweetDeck                 NaN               NaN
# 1                TweetDeck                 NaN               NaN
# 2  Twitter for Advertisers                 NaN               NaN
# 3                TweetDeck                 NaN               NaN
# 4                TweetDeck                 NaN               NaN
#
#   reply_to_screen_name  is_quote  ...  retweet_count  country_code  \
# 0                  NaN     False  ...              2           NaN
# 1                  NaN     False  ...              1           NaN
# 2                  NaN     False  ...              0           NaN
# 3                  NaN     False  ...              3           NaN
# 4                  NaN     False  ...              0           NaN
#
#    place_full_name place_type followers_count friends_count  account_lang  \
# 0              NaN        NaN            1671           169           NaN
# 1              NaN        NaN         4915788           775           NaN
# 2              NaN        NaN              43           266           NaN
# 3              NaN        NaN         1372231           161           NaN
# 4              NaN        NaN           13474          2557           NaN
#
#      account_created_at  verified lang
# 0  2017-01-05T18:17:00Z     False   es
# 1  2009-06-04T21:26:24Z      True   tl
# 2  2020-03-04T01:43:19Z     False   th
# 3  2009-11-24T02:03:16Z      True   tl
# 4  2018-09-19T19:40:04Z     False   es
#
# [5 rows x 22 columns]

# %%
# display columns
df.columns
# Out:
# Index(['status_id', 'user_id', 'created_at', 'screen_name', 'text', 'source',
#        'reply_to_status_id', 'reply_to_user_id', 'reply_to_screen_name',
#        'is_quote', 'is_retweet', 'favourites_count', 'retweet_count',
#        'country_code', 'place_full_name', 'place_type', 'followers_count',
#        'friends_count', 'account_lang', 'account_created_at', 'verified',
#        'lang'],
#       dtype='object')

# %% [markdown]
# # Cleaning Data

# %%
# dropping columns
tweet = df.copy()
tweet.drop(['status_id','user_id','screen_name','source','reply_to_status_id','reply_to_user_id','is_retweet','place_full_name','place_type','reply_to_screen_name','is_quote','followers_count','friends_count','account_lang','account_created_at','verified'],axis=1, inplace = True)
tweet.head()
# Out:
#              created_at                                               text  \
# 0  2020-04-16T00:00:00Z  Para complementar la higiene de tus manos, el ...
# 1  2020-04-16T00:00:00Z  PWDs from Tahanang Walang Hagdan get aid amid ...
# 2  2020-04-16T00:00:00Z  #France ได้รับความทุกข์ทรมานจาก # ชุดการแยกตัว...
# 3  2020-04-16T00:00:00Z  Target ng Department of Health na magkaroon ng...
# 4  2020-04-16T00:00:00Z  La @SSalud_mx lanzó una nueva convocatoria esp...
#
#    favourites_count  retweet_count country_code lang
# 0              1828              2          NaN   es
# 1              5449              1          NaN   tl
# 2                27              0          NaN   th
# 3               578              3          NaN   tl
# 4              5743              0          NaN   es

# %%
# filtering data with 'country_code = IN' and 'language = en'
tweet =tweet[(tweet.country_code == "IN") & (tweet.lang == "en")].reset_index(drop = True)
tweet.drop(['country_code','lang'],axis=1,inplace=True)
tweet.head()
# Out:
#              created_at                                               text  \
# 0  2020-04-16T00:22:06Z  Interesting Read. A Four point strategy beyond...
# 1  2020-04-16T00:31:50Z  @Imamofpeace China sneezed - world freezed.\n\...
# 2  2020-04-16T00:33:14Z  The poor in India are starving, the public is ...
# 3  2020-04-16T00:40:40Z  We are not stuck at home we are safe at home.....
# 4  2020-04-16T00:50:40Z  I wish to contribute a little amount to our lo...
#
#    favourites_count  retweet_count
# 0               841              0
# 1               664              0
# 2              5134              1
# 3               230              0
# 4                 5              0

# %%
# created_at column
tweet["created_at"] = tweet["created_at"].apply(lambda i:(int(i.split("T")[1].split(":")[0])+int(i.split("T")[1].split(":")[1])/60))

# %%
# shape
tweet.shape
# Out:
# (1661, 4)

# %%
# check missing values
tweet.isna().sum()
# Out:
# created_at          0
# text                0
# favourites_count    0
# retweet_count       0
# dtype: int64

# %%
# data preprocessing
for i in range(tweet.shape[0]) :
    tweet['text'][i] = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|(#[A-Za-z0-9]+)", " ", tweet['text'][i]).split()).lower()
tweet['text'].head()
# Out:
# 0    interesting read a four point strategy beyond ...
# 1    china sneezed world freezed covid 19 chinesevi...
# 2    the poor in india are starving the public is t...
# 3    we are not stuck at home we are safe at home s...
# 4    i wish to contribute a little amount to our lo...
# Name: text, dtype: object

# %% [markdown]
# ## Top 5 most favourited tweets:

# %%
fav = tweet[['favourites_count','text']].sort_values('favourites_count',ascending = False)[:5].reset_index()
for i in range(5):
    print(i,']', fav['text'][i],'\n')
# Out:
# 0 ] for the sake of the country please spell out the strategy as there is no vaccine or medicine for covid 19
#
# 1 ] i do not want any credit i just want the people of the country to be free from covid 19 whether the government believes it or not we will continue to play the role of positive opposition and keep giving our suggestions ji rahulspeaksforindia
#
# 2 ] the economic slowdown in the country is growing at a very rapid pace after covid19 the employment situation is deteriorating bjp government should help the poorest 20 of the people under the nyay scheme ji rahulspeaksforindia
#
# 3 ] we are in a limbo right now i write my views on the covid 19 and it s impact on the economy in the business standard article read more covid 19
#
# 4 ] lockdown is in no way a solution to the covid19 lockdown is like a pause button when we come out of the lockdown the virus is going to start its work again congress leader rahul gandhi rahulspeaksforindia

# %% [markdown]
# ## Top 5 most retweeted tweets:

# %%
retweet = tweet[['retweet_count','text']].sort_values('retweet_count',ascending = False)[:5].reset_index()
for i in range(5):
    print(i,']', retweet['text'][i],'\n')
# Out:
# 0 ] a 25 member team from the kottayam medical college who were a part of the team treating 5 patients including a 93 year old headed to kasargod for strengthening the functioning of the state of the art covid hospital covid19 covidkerala keralafightscovid
#
# 1 ] because hunger cannot wait join us in our mission to protect vulnerable groups donate at beatthevirus covid19 coronarelief
#
# 2 ] after one month of fighting againt covid19 he has came with strategic
#
# 3 ] ajayks sant shri asharamji bapu established yuwa seva sangh mahila utthan mandal these organizations provide food or basic essentials to poor peoples at this critical time of coronaviruspandemic
#
# 4 ] sober press conference by on covid19 did not get into a blame game mode and refrained from blaming modi in person and ensured that pc does not turn into us vs them match

# %% [markdown]
# # Number of Tweets/Hour

# %%
plt.figure(1, figsize=(10,6))
plt.hist(tweet["created_at"],bins = 24);
plt.xlabel('Hours',size = 15)
plt.ylabel('No. of Tweets',size = 15)
plt.title('No. of Tweets per Hour',size = 15)
# Out:
# Text(0.5, 1.0, 'No. of Tweets per Hour')

# %% [markdown]
# # Word Cloud :

# %%
def show_wordcloud(data , title = None):
    wordcloud = WordCloud(background_color='black',stopwords=stopwords,max_words=200,max_font_size=40).generate(str(data))
  
    fig = plt.figure(1, figsize=(15, 15))
    plt.axis('off')
    plt.title(title, size = 25)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.show()

show_wordcloud(tweet['text'])

# %% [markdown]
# The following words can be seen: covid, fear, chinese, starving, strategy.

# %% [markdown]
# ### Removing Stopwords

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
#Removing Stop Words
tweet['text'] = tweet['text'].apply(lambda tweets: ' '.join([word for word in tweets.split() if word not in stopwords]))
tweet['text'].head()
# Out:
# 0    interesting read four point strategy beyond co...
# 1    china sneezed world freezed covid 19 chinesevi...
# 2    poor india starving public troubled epidemic c...
# 3    stuck home safe home sitting lucknow rememberi...
# 4    wish contribute little amount lovable pm s pm ...
# Name: text, dtype: object

# %% [markdown]
# ## Analyzing Text for Sentiment

# %% [markdown]
# #### Analyzing text using TextBlob to predict the sentiment of the text and categorise it as 'Positive', 'Negative' or 'Neutral'.

# %%
tweet['sentiment'] = ' '
tweet['polarity'] = None
for i,tweets in enumerate(tweet.text) :
    blob = TextBlob(tweets)
    tweet['polarity'][i] = blob.sentiment.polarity
    if blob.sentiment.polarity > 0 :
        tweet['sentiment'][i] = 'positive'
    elif blob.sentiment.polarity < 0 :
        tweet['sentiment'][i] = 'negative'
    else :
        tweet['sentiment'][i] = 'neutral'
tweet.head()
# Out:
#    created_at                                               text  \
# 0    0.366667  interesting read four point strategy beyond co...
# 1    0.516667  china sneezed world freezed covid 19 chinesevi...
# 2    0.550000  poor india starving public troubled epidemic c...
# 3    0.666667  stuck home safe home sitting lucknow rememberi...
# 4    0.833333  wish contribute little amount lovable pm s pm ...
#
#    favourites_count  retweet_count sentiment  polarity
# 0               841              0  positive  0.333333
# 1               664              0   neutral         0
# 2              5134              1  negative      -0.3
# 3               230              0  positive     0.675
# 4                 5              0  positive  0.304167

# %%
print(tweet.sentiment.value_counts())
sns.countplot(x='sentiment', data = tweet);
# Out:
# positive    845
# neutral     565
# negative    251
# Name: sentiment, dtype: int64

# %% [markdown]
# ## Sentiment Distribution

# %%
plt.figure(figsize=(10,6))
sns.distplot(tweet['polarity'], bins=30)
plt.title('Sentiment Distribution',size = 15)
plt.xlabel('Polarity',size = 15)
plt.ylabel('Frequency',size = 15)
plt.show();

# %% [markdown]
# ## Using Word Clouds to see the higher fequency words from each sentiment

# %%
pos = tweet['text'][tweet['sentiment'] == 'positive']
show_wordcloud(pos , 'POSITIVE')

neg = tweet['text'][tweet['sentiment'] == 'negative']
show_wordcloud(neg , 'NEGATIVE')

neutral = tweet['text'][tweet['sentiment'] == 'neutral']
show_wordcloud(neutral , 'NEUTRAL')

# %%
count = pd.DataFrame(tweet.groupby('sentiment')['favourites_count'].sum())
count.head()
# Out:
#            favourites_count
# sentiment
# negative            2111532
# neutral             4026156
# positive            7313998

# %% [markdown]
# # Most frequently appearing words

# %%
words = []
words = [word for i in tweet.text for word in i.split()]

# %%
freq = Counter(words).most_common(30)
freq = pd.DataFrame(freq)
freq.columns = ['word', 'frequency']
freq.head()
# Out:
#           word  frequency
# 0        covid        841
# 1           19        755
# 2      covid19        569
# 3  coronavirus        402
# 4     lockdown        302

# %%
plt.figure(figsize = (10, 10))
sns.barplot(y="word", x="frequency",data=freq);

# %%
tweet.to_csv('tweet.csv',index=False)

# %% [markdown]
# # Conclusion
# We can conclude that mostly people have a positive and neutral sentiment towards the start of Lockdown-2.
